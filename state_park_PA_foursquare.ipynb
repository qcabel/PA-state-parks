# %% [markdown]
# ## FourSquare API on PA state parks

# %%
import numpy as np
import pandas as pd
import requests

from geopy.geocoders import Nominatim

# %%
# load the list of PA state parks
df_park = pd.read_csv('state_park_PA.csv')
df_park.shape
# Out:
# (121, 7)

# %%
# get fourSquare config ids
fsqr_config = pd.read_csv('foursquare_config.txt', header=None)
CLIENT_ID = fsqr_config.iloc[1][0]
CLIENT_SECRET = fsqr_config.iloc[3][0]
VERSION = '20200905' 
LIMIT = 100

# %%
# convert an address into latitude and longitude values
geolocator = Nominatim(user_agent="pa_explorer")

latitude = np.empty(df_park.shape[0])
longitude = np.empty(df_park.shape[0])
latitude[:] = np.nan
longitude[:] = np.nan

for ind in range(df_park.shape[0]):
    address = '{}, PA'.format(df_park['Park name'][ind])

    location = geolocator.geocode(address)
    if location:
        latitude[ind] = location.latitude
        longitude[ind] = location.longitude
    print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude[ind], longitude[ind]))
    
np.sum(np.isnan(longitude))
# Big Spring State Forest Picnic Area; 
# French Creek State Park, PA; 
# Kings Gap Environmental Education and Training Center
# Out:
# The geograpical coordinate of Allegheny Islands State Park, PA are 40.5371096, -79.82333755703746.
# The geograpical coordinate of Archbald Pothole State Park, PA are 41.50989920000001, -75.56838568277055.
# The geograpical coordinate of Bald Eagle State Park, PA are 41.0417311, -77.6030495.
# The geograpical coordinate of Beltzville State Park, PA are 40.8684893, -75.60191225614028.
# The geograpical coordinate of Bendigo State Park, PA are 41.530494399999995, -78.6278593808558.
# The geograpical coordinate of Benjamin Rush State Park, PA are 40.11494625, -74.97665930932364.
# The geograpical coordinate of Big Pocono State Park, PA are 41.0424311, -75.35193912576602.
# The geograpical coordinate of Big Spring State Forest Picnic Area, PA are nan, nan.
# The geograpical coordinate of Black Moshannon State Park, PA are 40.90129, -78.06456571768157.
# The geograpical coordinate of Blue Knob State Park, PA are 40.2786873, -78.5811281.
# The geograpical coordinate of Boyd Big Tree Preserve Conservation Area, PA are 40.3600594, -76.8679419.
# The geograpical coordinate of Buchanan's Birthplace State Park, PA are 39.8708, -77.954.
# The geograpical coordinate of Bucktail State Park Natural Area, PA are 41.2756, -77.9464.
# The geograpical coordinate of Caledonia State Park, PA are 39.9117587, -77.483043.
# The geograpical coordinate of Canoe Creek State Park, PA are 40.4867383, -78.2697339.
# The geograpical coordinate of Chapman State Park, PA are 41.751664000000005, -79.17491756587077.
# The geograpical coordinate of Cherry Springs State Park, PA are 41.662747949999996, -77.82220020751974.
# The geograpical coordinate of Clear Creek State Park, PA are 41.32888985, -79.08965604809262.
# The geograpical coordinate of Codorus State Park, PA are 39.7701008, -76.9363681.
# The geograpical coordinate of Colonel Denning State Park, PA are 40.2734186, -77.4163747.
# The geograpical coordinate of Colton Point State Park, PA are 41.70182885, -77.4655429886938.
# The geograpical coordinate of Cook Forest State Park, PA are 41.31912185, -79.20078587367158.
# The geograpical coordinate of Cowans Gap State Park, PA are 39.99157785, -77.92951251450975.
# The geograpical coordinate of Delaware Canal State Park, PA are 40.688024850000005, -75.20540393809848.
# The geograpical coordinate of Denton Hill State Park, PA are 41.7686959, -77.83099760024946.
# The geograpical coordinate of Elk State Park, PA are 41.60159045, -78.55910262976539.
# The geograpical coordinate of Erie Bluffs State Park, PA are 42.01505215, -80.38717290569167.
# The geograpical coordinate of Evansburg State Park, PA are 40.2101051, -75.3704559.
# The geograpical coordinate of Fort Washington State Park, PA are 40.107766, -75.2204636544098.
# The geograpical coordinate of Fowlers Hollow State Park, PA are 40.271237, -77.5806836373452.
# The geograpical coordinate of Frances Slocum State Park, PA are 41.3386649, -75.89257054461729.
# The geograpical coordinate of French Creek State Park, PA are nan, nan.
# The geograpical coordinate of Gifford Pinchot State Park, PA are 40.07669955, -76.88768841902431.
# The geograpical coordinate of Gouldsboro State Park, PA are 41.2100114, -75.45679628957643.
# The geograpical coordinate of Greenwood Furnace State Park, PA are 40.647032300000006, -77.7626841653609.
# The geograpical coordinate of Hickory Run State Park, PA are 41.0220693, -75.68104873901555.
# The geograpical coordinate of Hillman State Park, PA are 40.452264150000005, -80.41586795140304.
# The geograpical coordinate of Hills Creek State Park, PA are 41.8134068, -77.1663603.
# The geograpical coordinate of Hyner Run State Park, PA are 41.3592345, -77.6330394.
# The geograpical coordinate of Hyner View State Park, PA are 41.3267346, -77.6241501.
# The geograpical coordinate of Jacobsburg Environmental Education Center, PA are 40.782875950000005, -75.29289024545699.
# The geograpical coordinate of Jennings Environmental Education Center, PA are 41.0091949, -80.0027487.
# The geograpical coordinate of Joseph E. Ibberson Conservation Area, PA are 40.4303, -76.8567.
# The geograpical coordinate of Kettle Creek State Park, PA are 41.390723050000005, -77.92801754890871.
# The geograpical coordinate of Keystone State Park, PA are 40.37347025, -79.38077274773602.
# The geograpical coordinate of Kings Gap Environmental Education and Training Center, PA are nan, nan.
# The geograpical coordinate of Kinzua Bridge State Park, PA are 41.7581417, -78.5871552.
# The geograpical coordinate of Kooser State Park, PA are 40.0603526, -79.2300316.
# The geograpical coordinate of Lackawanna State Park, PA are 41.56942375, -75.7088928633612.
# The geograpical coordinate of Laurel Hill State Park, PA are 40.0134084, -79.258921.
# The geograpical coordinate of Laurel Mountain State Park, PA are 40.1608771, -79.1609319503279.
# The geograpical coordinate of Laurel Ridge State Park, PA are 40.25838325, -79.07256599216191.
# The geograpical coordinate of Laurel Summit State Park, PA are 40.1017417, -79.178086.
# The geograpical coordinate of Lehigh Gorge State Park, PA are 40.9907365, -75.71436368074316.
# The geograpical coordinate of Leonard Harrison State Park, PA are 41.6967376, -77.4541464.
# The geograpical coordinate of Linn Run State Park, PA are 40.1564624, -79.2311431.
# The geograpical coordinate of Little Buffalo State Park, PA are 40.45248035, -77.18253099968095.
# The geograpical coordinate of Little Pine State Park, PA are 41.3792378, -77.3396984.
# The geograpical coordinate of Locust Lake State Park, PA are 40.783422, -76.1413265.
# The geograpical coordinate of Lyman Run State Park, PA are 41.72284875, -77.76256243071478.
# The geograpical coordinate of Marsh Creek State Park, PA are 40.07045385, -75.7302167630001.
# The geograpical coordinate of Maurice K. Goddard State Park, PA are 41.400600999999995, -80.10526489052123.
# The geograpical coordinate of McCalls Dam State Park, PA are 41.017, -77.1826.
# The geograpical coordinate of McConnells Mill State Park, PA are 40.938636149999994, -80.17780387054972.
# The geograpical coordinate of Memorial Lake State Park, PA are 40.42056075, -76.59830987315397.
# The geograpical coordinate of Milton State Park, PA are 41.0239106, -76.85719393861348.
# The geograpical coordinate of Mont Alto State Park, PA are 39.8391777, -77.5377298.
# The geograpical coordinate of Moraine State Park, PA are 40.959343000000004, -80.05888164894459.
# The geograpical coordinate of Mt. Pisgah State Park, PA are 41.801681599999995, -76.67917110668995.
# The geograpical coordinate of Nescopeck State Park, PA are 41.073012, -75.91362157626463.
# The geograpical coordinate of Neshaminy State Park, PA are 40.079065549999996, -74.91613756160403.
# The geograpical coordinate of Nockamixon State Park, PA are 40.45789445, -75.23489526880626.
# The geograpical coordinate of Nolde Forest Environmental Education Center, PA are 40.272244, -75.947743.
# The geograpical coordinate of Norristown Farm Park, PA are 40.1429435, -75.34786711546997.
# The geograpical coordinate of Ohiopyle State Park, PA are 39.86841335, -79.4861154629893.
# The geograpical coordinate of Oil Creek State Park, PA are 41.5444808, -79.65013305970308.
# The geograpical coordinate of Ole Bull State Park, PA are 41.5359003, -77.7152656.
# The geograpical coordinate of Parker Dam State Park, PA are 41.1938633, -78.5119696.
# The geograpical coordinate of Patterson State Park, PA are 41.696037200000006, -77.893082829934.
# The geograpical coordinate of Penn-Roosevelt State Park, PA are 40.72602845, -77.70237370126083.
# The geograpical coordinate of Pine Grove Furnace State Park, PA are 40.030424350000004, -77.30193057044056.
# The geograpical coordinate of Poe Paddy State Park, PA are 40.834205850000004, -77.41787173808913.
# The geograpical coordinate of Poe Valley State Park, PA are 40.8200256, -77.4725739.
# The geograpical coordinate of Point State Park, PA are 40.441514350000006, -80.01008575399894.
# The geograpical coordinate of Presque Isle State Park, PA are 42.142995, -80.13609030816764.
# The geograpical coordinate of Prince Gallitzin State Park, PA are 40.6750647, -78.5369652.
# The geograpical coordinate of Promised Land State Park, PA are 41.31284365, -75.21021315504281.
# The geograpical coordinate of Prompton State Park, PA are 41.6084199, -75.3329561.
# The geograpical coordinate of Prouty Place State Park, PA are 41.657566, -77.9124982.
# The geograpical coordinate of Pymatuning State Park, PA are 41.59256695, -80.50988858272981.
# The geograpical coordinate of R. B. Winter State Park, PA are 40.9941725, -77.1893037.
# The geograpical coordinate of Raccoon Creek State Park, PA are 40.51761045000001, -80.45803128032529.
# The geograpical coordinate of Ralph Stover State Park, PA are 40.434521700000005, -75.09927468131067.
# The geograpical coordinate of Ravensburg State Park, PA are 41.1100727, -77.243025.
# The geograpical coordinate of Reeds Gap State Park, PA are 40.7217364, -77.4752722.
# The geograpical coordinate of Ricketts Glen State Park, PA are 41.33284675, -76.27929838443805.
# The geograpical coordinate of Ridley Creek State Park, PA are 39.9559436, -75.4496427.
# The geograpical coordinate of Ryerson Station State Park, PA are 39.88515845, -80.44362884537824.
# The geograpical coordinate of S. B. Elliott State Park, PA are 41.1130063, -78.5258953.
# The geograpical coordinate of Salt Springs State Park, PA are 41.91037285, -75.8710245318978.
# The geograpical coordinate of Samuel S. Lewis State Park, PA are 39.9951253, -76.54834337627514.
# The geograpical coordinate of Sand Bridge State Park, PA are 40.9984115, -77.1146901.
# The geograpical coordinate of Shawnee State Park, PA are 40.0261916, -78.6355746.
# The geograpical coordinate of Shikellamy State Park, PA are 40.8806408, -76.8044103.
# The geograpical coordinate of Sinnemahoning State Park, PA are 41.4483974, -78.0491684.
# The geograpical coordinate of Sizerville State Park, PA are 41.595064, -78.1947308.
# The geograpical coordinate of Susquehanna State Park, PA are 41.222577, -77.0827462.
# The geograpical coordinate of Susquehannock State Park, PA are 39.8059961, -76.2839784.
# The geograpical coordinate of Swatara State Park, PA are 40.49245, -76.53565347951255.
# The geograpical coordinate of Tobyhanna State Park, PA are 41.2245567, -75.41012415023235.
# The geograpical coordinate of Trough Creek State Park, PA are 40.3286879, -78.1313961.
# The geograpical coordinate of Tuscarora State Park, PA are 40.8000885, -76.0246521.
# The geograpical coordinate of Tyler State Park, PA are 40.2342291, -74.98154232912972.
# The geograpical coordinate of Upper Pine Bottom State Park, PA are 41.3189, -77.4214.
# The geograpical coordinate of Varden Conservation Area, PA are 41.4867, -75.3892.
# The geograpical coordinate of Warriors Path State Park, PA are 40.19693185, -78.2573487881887.
# The geograpical coordinate of Washington Crossing Historic Park, PA are 40.2976074, -74.876276.
# The geograpical coordinate of Whipple Dam State Park, PA are 40.6867695, -77.86283790031524.
# The geograpical coordinate of White Clay Creek Preserve, PA are 39.7435742, -75.7691255.
# The geograpical coordinate of Worlds End State Park, PA are 41.46181755, -76.57609331713148.
# The geograpical coordinate of Yellow Creek State Park, PA are 40.5684011, -79.0264199.
# 3

# %%
df_park['latitude'] = latitude
df_park['longitude'] = longitude

# %%
df_park
# Out:
#                              Park name County or counties  \
# 0         Allegheny Islands State Park   Allegheny County
# 1          Archbald Pothole State Park  Lackawanna County
# 2                Bald Eagle State Park      Centre County
# 3                Beltzville State Park      Carbon County
# 4                   Bendigo State Park         Elk County
# ..                                 ...                ...
# 116  Washington Crossing Historic Park       Bucks County
# 117             Whipple Dam State Park  Huntingdon County
# 118          White Clay Creek Preserve     Chester County
# 119              Worlds End State Park    Sullivan County
# 120            Yellow Creek State Park     Indiana County
#
#          Area in acres (ha) Date founded  \
# 0          43 acres (17 ha)         1980
# 1         150 acres (61 ha)         1964
# 2    5,900 acres (2,388 ha)         1971
# 3    2,973 acres (1,203 ha)         1972
# 4         100 acres (40 ha)         1959
# ..                      ...          ...
# 116      500 acres (202 ha)         2016
# 117      256 acres (104 ha)         1928
# 118    1,255 acres (508 ha)         1984
# 119      780 acres (316 ha)         1932
# 120  3,140 acres (1,271 ha)         1963
#
#                            Stream(s) and / or lake(s)  \
# 0                                     Allegheny River
# 1                                                None
# 2    Bald Eagle Creek, Foster Joseph Sayers Reservoir
# 3                     Pohopoco Creek, Beltzville Lake
# 4                           East Branch Clarion River
# ..                                                ...
# 116                                    Delaware River
# 117                                      Whipple Lake
# 118                                  White Clay Creek
# 119                                   Loyalsock Creek
# 120                   Yellow Creek, Yellow Creek Lake
#
#                                                Remarks  Image   latitude  \
# 0    Three alluvial islands near Pittsburgh with no...    NaN  40.537110
# 1    One of world's largest potholes, 38 ft (12 m) ...    NaN  41.509899
# 2    1,730 acre (700 ha) U.S. Army Corps of Enginee...    NaN  41.041731
# 3    U.S. Army Corps of Engineers lake is 949 acres...    NaN  40.868489
# 4    Only 20 acres (8.1 ha) developed, name a corru...    NaN  41.530494
# ..                                                 ...    ...        ...
# 116  Site of George Washington's crossing of the De...    NaN  40.297607
# 117  There was a camp for Boy Scouts, Girl Scouts, ...    NaN  40.686769
# 118  Park was donated by DuPont to preserve "divers...    NaN  39.743574
# 119  A "Must See Park" known for trout fishing, whi...    NaN  41.461818
# 120  Crossed by the Kittanning Path, a major east–w...    NaN  40.568401
#
#      longitude
# 0   -79.823338
# 1   -75.568386
# 2   -77.603049
# 3   -75.601912
# 4   -78.627859
# ..         ...
# 116 -74.876276
# 117 -77.862838
# 118 -75.769126
# 119 -76.576093
# 120 -79.026420
#
# [121 rows x 9 columns]

# %%
# test API
lat = df_park['latitude'][0]
lng = df_park['longitude'][0]
radius = 1000 # meters
# create the API request URL for venue recommendation
# "ll" can be substitude by the option "near" with park names directly [automatically resolve geolocate, maybe less reliable]
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lng, 
    radius, 
    LIMIT)

# make the GET request
results = requests.get(url).json()#["response"]['groups'][0]['items']

# %%
results['response']['groups'][0]['items'][1]['venue']
# Out:
# {'id': '4f49199be4b0e7e90f5f5b62',
#  'name': 'Beltzville Lake State Park',
#  'location': {'address': 'Beltzville',
#   'lat': 40.86090941367579,
#   'lng': -75.62565338423482,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.86090941367579,
#     'lng': -75.62565338423482}],
#   'postalCode': '18235',
#   'cc': 'US',
#   'city': 'Lehighton',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['Beltzville', 'Lehighton, PA 18235', 'United States']},
#  'categories': [{'id': '5bae9231bedf3950379f89d0',
#    'name': 'State / Provincial Park',
#    'pluralName': 'State / Provincial Parks',
#    'shortName': 'State / Provincial Park',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#     'suffix': '.png'},
#    'primary': True}],
#  'photos': {'count': 0, 'groups': []}}

# %% [markdown]
# #### Search for the state park venue_id

# %%
categId = '5bae9231bedf3950379f89d0' # category id for "State / Provincial Park"
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lng,
    categId,
    radius, 
    LIMIT)
venue_park_results = requests.get(url).json()

# %%
venue_park_results['response']['venues'][0]
# Out:
# {'id': '4d759203497fa1431e19d225',
#  'name': 'Allegheny Islands State Park',
#  'location': {'lat': 40.536862031010415,
#   'lng': -79.82472896575928,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.536862031010415,
#     'lng': -79.82472896575928}],
#   'distance': 120,
#   'postalCode': '15238',
#   'cc': 'US',
#   'city': 'Harmar Township',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['Harmar Township, PA 15238', 'United States']},
#  'categories': [{'id': '5bae9231bedf3950379f89d0',
#    'name': 'State / Provincial Park',
#    'pluralName': 'State / Provincial Parks',
#    'shortName': 'State / Provincial Park',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1599713447',
#  'hasPerk': False}

# %% [markdown]
# #### Get some details about the state park (Premium endpoint)

# %%
VENUE_ID = '4f49199be4b0e7e90f5f5b62'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(VENUE_ID, CLIENT_ID, CLIENT_SECRET, VERSION)
venue_results = requests.get(url).json()
venue_results
# Out:
# {'meta': {'code': 200, 'requestId': '5f59b2c47008ac04a89b3377'},
#  'response': {'venue': {'id': '4f49199be4b0e7e90f5f5b62',
#    'name': 'Beltzville Lake State Park',
#    'contact': {},
#    'location': {'address': 'Beltzville',
#     'lat': 40.86090941367579,
#     'lng': -75.62565338423482,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.86090941367579,
#       'lng': -75.62565338423482}],
#     'postalCode': '18235',
#     'cc': 'US',
#     'city': 'Lehighton',
#     'state': 'PA',
#     'country': 'United States',
#     'formattedAddress': ['Beltzville',
#      'Lehighton, PA 18235',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/beltzville-lake-state-park/4f49199be4b0e7e90f5f5b62',
#    'categories': [{'id': '5bae9231bedf3950379f89d0',
#      'name': 'State / Provincial Park',
#      'pluralName': 'State / Provincial Parks',
#      'shortName': 'State / Provincial Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'},
#      'primary': True},
#     {'id': '4bf58dd8d48988d161941735',
#      'name': 'Lake',
#      'pluralName': 'Lakes',
#      'shortName': 'Lake',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#       'suffix': '.png'}}],
#    'verified': False,
#    'stats': {'tipCount': 10},
#    'likes': {'count': 24,
#     'groups': [{'type': 'others', 'count': 24, 'items': []}],
#     'summary': '24 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 7.7,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 35,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 90,
#     'groups': [{'type': 'venue',
#       'name': 'Venue photos',
#       'count': 90,
#       'items': [{'id': '4fdcc557e4b0ec5a8ef976ab',
#         'createdAt': 1339868503,
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'https://foursquare.com/download/#/iphone'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/TsQa-G5UtwKWZaC2vy0ycQjrED_1-RsXc_28zkjxCUw.jpg',
#         'width': 720,
#         'height': 537,
#         'user': {'id': '1060616',
#          'firstName': 'Robert',
#          'lastName': 'B',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/3U5B1RKUFDE3UPI5.jpg'}},
#         'visibility': 'public'}]}]},
#    'reasons': {'count': 0, 'items': []},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1330190747,
#    'tips': {'count': 10,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 10,
#       'items': [{'id': '5b9ee50b35811b002cfc1ee7',
#         'createdAt': 1537139979,
#         'text': 'Fishing is rewarding.  Try and be in a boat while doing so.  The tourism can inhibit the experience.  Lots of places to enjoy.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/5b9ee50b35811b002cfc1ee7',
#         'lang': 'en',
#         'likes': {'count': 0, 'groups': []},
#         'logView': True,
#         'agreeCount': 1,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'id': '76659734',
#          'firstName': 'Jason',
#          'lastName': 'S',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/76659734_VLrTZEy9_0FDp9XGs1oI2p0z2q91rYSiylki2smZCdMlwID1X8MnuqhVb0p96DIh-igmFo4OD.jpg'}},
#         'authorInteractionType': 'liked'}]}]},
#    'shortUrl': 'http://4sq.com/wk0kg9',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 10,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 10,
#       'items': [{'id': '4e55a537cc3f051f81d5a8e1',
#         'name': 'Jim Thorpe,PA Hidden Gems #visitUS',
#         'description': 'Burial site of Olympic athlete Jim Thorpe, plenty of coal-mining history & no shortage of outdoor activities to keep you occupied. Several great restaurants,shops,museums are here. #visitUS #4sqCities',
#         'type': 'others',
#         'user': {'id': '10369024',
#          'firstName': 'Angie',
#          'lastName': 'P',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/10369024_n6IFs8RM_gfuMsQGIfnJqSUIhljl5psP9gtj70BWocgT4KzmULyWyCzhoS4rwDdKmPdgeSW4a.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': True,
#         'url': '/user/10369024/list/jim-thorpepa-hidden-gems-visitus',
#         'canonicalUrl': 'https://foursquare.com/user/10369024/list/jim-thorpepa-hidden-gems-visitus',
#         'createdAt': 1314235703,
#         'updatedAt': 1502997218,
#         'photo': {'id': '4ef7ed97b63446a509245ab2',
#          'createdAt': 1324871063,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/CXHXS0KW2LA4IK3J0EEOVZM5CL13OTOE34PZIMYNDIZHHUVS.jpg',
#          'width': 720,
#          'height': 333,
#          'user': {'id': '10369024',
#           'firstName': 'Angie',
#           'lastName': 'P',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/10369024_n6IFs8RM_gfuMsQGIfnJqSUIhljl5psP9gtj70BWocgT4KzmULyWyCzhoS4rwDdKmPdgeSW4a.jpg'}},
#          'visibility': 'public'},
#         'followers': {'count': 25},
#         'listItems': {'count': 43,
#          'items': [{'id': 't4c1448c2a9c220a10667579d',
#            'createdAt': 1320937855,
#            'photo': {'id': '4e91b683775bfdaabcccfeaf',
#             'createdAt': 1318172291,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/U1ZRWZWWOQI1ZQSKO3FFCBDG4JUZKZGFICN4ZEF0SMQNSB2N.jpg',
#             'width': 720,
#             'height': 431,
#             'user': {'id': '10527532',
#              'firstName': 'Ben',
#              'lastName': 'K',
#              'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#               'suffix': '/IZUSLAZ1PZQNXUG5.jpg'}},
#             'visibility': 'public'}}]}},
#        {'id': '4eadb6a47beb16960360932e',
#         'name': 'Whitewater Kayaking, Great Outdoors and Outfitters',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '10369024',
#          'firstName': 'Angie',
#          'lastName': 'P',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/10369024_n6IFs8RM_gfuMsQGIfnJqSUIhljl5psP9gtj70BWocgT4KzmULyWyCzhoS4rwDdKmPdgeSW4a.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': True,
#         'url': '/user/10369024/list/whitewater-kayaking-great-outdoors-and-outfitters',
#         'canonicalUrl': 'https://foursquare.com/user/10369024/list/whitewater-kayaking-great-outdoors-and-outfitters',
#         'createdAt': 1320007332,
#         'updatedAt': 1423159470,
#         'photo': {'id': '4ef7ec7193ad7cf2ead5d13b',
#          'createdAt': 1324870769,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/NPATRLXFYV4UHOGAOB4WADOCHINMAJVM3FMTPVZEEAA2UVPM.jpg',
#          'width': 720,
#          'height': 478,
#          'user': {'id': '10369024',
#           'firstName': 'Angie',
#           'lastName': 'P',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/10369024_n6IFs8RM_gfuMsQGIfnJqSUIhljl5psP9gtj70BWocgT4KzmULyWyCzhoS4rwDdKmPdgeSW4a.jpg'}},
#          'visibility': 'public'},
#         'followers': {'count': 2},
#         'listItems': {'count': 42,
#          'items': [{'id': 't4c1448c2a9c220a10667579d',
#            'createdAt': 1320937851,
#            'photo': {'id': '4e91b683775bfdaabcccfeaf',
#             'createdAt': 1318172291,
#             'prefix': 'https://fastly.4sqi.net/img/general/',
#             'suffix': '/U1ZRWZWWOQI1ZQSKO3FFCBDG4JUZKZGFICN4ZEF0SMQNSB2N.jpg',
#             'width': 720,
#             'height': 431,
#             'user': {'id': '10527532',
#              'firstName': 'Ben',
#              'lastName': 'K',
#              'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#               'suffix': '/IZUSLAZ1PZQNXUG5.jpg'}},
#             'visibility': 'public'}}]}},
#        {'id': '4f8f7f1ae4b0d6c8aa0ea9f2',
#         'name': 'Highways & Byways',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '203356',
#          'firstName': 'Ashley',
#          'lastName': 'R',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/2PNB0MGMJN4I41IS.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/akaleirose/list/highways--byways',
#         'canonicalUrl': 'https://foursquare.com/akaleirose/list/highways--byways',
#         'createdAt': 1334804250,
#         'updatedAt': 1414538324,
#         'photo': {'id': '506a15edebcab040dbfdf005',
#          'createdAt': 1349129709,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/5339676_s2pl0IEvCMOxiSzJvxUJenLhU4oR0iXewfFZ4njGlKg.jpg',
#          'width': 1000,
#          'height': 667,
#          'user': {'id': '5339676',
#           'firstName': 'Travel + Leisure',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/3MAPUHGXHTC3MWHJ.jpg'},
#           'type': 'page'},
#          'visibility': 'public'},
#         'followers': {'count': 16},
#         'listItems': {'count': 189,
#          'items': [{'id': 'v4f49199be4b0e7e90f5f5b62',
#            'createdAt': 1334805793}]}},
#        {'id': '5a9185e74c9be666d203effc',
#         'name': 'Lehigh Valley List',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '23169719',
#          'firstName': 'Jason',
#          'lastName': 'E',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/23169719-1MHN3OL4XSZKWFMX.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': True,
#         'url': '/user/23169719/list/lehigh-valley-list',
#         'canonicalUrl': 'https://foursquare.com/user/23169719/list/lehigh-valley-list',
#         'createdAt': 1519486439,
#         'updatedAt': 1531848123,
#         'followers': {'count': 1},
#         'listItems': {'count': 204,
#          'items': [{'id': 'v4f49199be4b0e7e90f5f5b62',
#            'user': {'id': '74859394',
#             'firstName': 'Christina',
#             'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#              'suffix': '/74859394_WGfE95eV_FS5kmVMPeGMBKtcFoJt9K8dKZjVnkWBVKUz8SFQs7BWp0Lyqgboo-RuEo0FLMMIc.jpg'},
#             'tips': {'count': 4},
#             'lists': {'groups': [{'type': 'created',
#                'count': 2,
#                'items': []}]},
#             'bio': ''},
#            'createdAt': 1530896099}]}}]}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': False,
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '1:00 PM–2:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': '11:00 AM–3:00 PM'},
#        {'renderedTime': '5:00 PM–7:00 PM'},
#        {'renderedTime': '9:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#        {'renderedTime': '9:00 AM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': '1:00 PM–6:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '11:00 AM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': 'Noon–8:00 PM'}],
#       'segments': []}]},
#    'seasonalHours': [],
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': []},
#    'bestPhoto': {'id': '4fdcc557e4b0ec5a8ef976ab',
#     'createdAt': 1339868503,
#     'source': {'name': 'Foursquare for iOS',
#      'url': 'https://foursquare.com/download/#/iphone'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/TsQa-G5UtwKWZaC2vy0ycQjrED_1-RsXc_28zkjxCUw.jpg',
#     'width': 720,
#     'height': 537,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '4fdcc557e4b0ec5a8ef976ab',
#      'value': -9400320},
#     'highlightTextColor': {'photoId': '4fdcc557e4b0ec5a8ef976ab',
#      'value': -16777216},
#     'algoVersion': 3}}}}

# %%
venue_results['response']['venue'].keys()
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])

# %%
venue_results['response']['venue']['rating']
# Out:
# 7.7

# %%
venue_results['response']['venue']['likes']
# Out:
# {'count': 24,
#  'groups': [{'type': 'others', 'count': 24, 'items': []}],
#  'summary': '24 Likes'}

# %% [markdown]
# ### State park accessibility based on venues nearby
